# %% [raw]
# Write each question and then add your answer:
# 1. Regarding a variable, which of the following statements is false?
# A: Can have at least two different values
#
# 2: In python, the type of -4.0 is:
# A: Float
#
# 3: Type of  True  is:
# A: bool
#
# 4: If a = np.dot(3, 4)then, type of a is ?
# A: numpy.int64
#
# 5:If  df.columns is:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')
# How can I select only columns:
# 'Age', 'Gender', 'GenderGroup'
#
# A:
# df.loc[:,['Age', 'Gender', 'GenderGroup']]
# df.iloc[:,[1, 2, 3]]
#
#
# Write the name that characterizes the data set
# A: GDP Per Capita (current US$)
#
# Write the organisation that generated it
# A: The World Bank
#
# Include an internet link where they can be downloaded online and submit as a spreadsheet along with your corresponding report.
# A: https://data.worldbank.org/indicator/NY.GDP.PCAP.CD?view=chart
#
# Describes the data set. What data does it contain?
# A: The data set contains a list of the countries of the world and its corresponding GDP per capita
#
# What are some of the questions you could answer with this data? List at least FIVE (do not answer the questions).
# Research questions (of interest).
#
# 1. How can I tell if a country is doing economically well?
# 2. Which country has a gdp per capita above 1000 USD?
# 3. What are the world's poorest countries?
# 4. What are the world's richest countries?
# 5. What is the average GDP per capita in europe?
# 6. How does the average GDP per capita in europe compare to africa?
#
#
# Which stakeholder (company, sector of society, decentralized body, government, etc.) would be interested in the questions you identified in point 6?
#
# United Nations and each countries government would be highly interested in knowing all countries GDP per capita.
